# %%
# pip install pymongo

# %%
# import json
# from pymongo import MongoClient

# # Replace these values with your MongoDB Atlas connection details
# mongo_uri = "mongodb+srv://qwerty123:qwerty123@cluster0.zrw3uzs.mongodb.net/LinReg"
# collection_name = "LinReg123"

# # Replace 'input.json' with the actual path to your JSON file
# json_file_path = 'output.json'

# # Read the JSON file
# with open(json_file_path, 'r') as json_file:
#     json_data = json.load(json_file)

# # Connect to MongoDB
# client = MongoClient(mongo_uri)
# db = client.get_database()  # Don't specify the database name here
# collection = db["LinReg123"]

# # Insert the JSON data into MongoDB
# collection.insert_many(json_data)

# print(f"JSON data from '{json_file_path}' has been inserted into MongoDB collection '{collection_name}'.")

# %%
# import json
# import pandas as pd
# # Specify the path to your JSON file
# json_file_path = 'output.json'

# # Open and read the JSON file
# with open(json_file_path, 'r') as file:
#     # Load the JSON data
#     data = json.load(file)

# # Now 'data' contains the contents of your JSON file
# # print(data)

# df = pd.DataFrame(data)
# df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# ...

# %%
import json

# Your JSON data as a string
json_data_string = '{"key": "value", "number": 42}'

# Load the JSON data from the string
data = json.loads(json_data_string)

# Now 'data' contains the parsed JSON data
print(data)
# Out:
# {'key': 'value', 'number': 42}

# %%
import pymongo
import json

# Replace these values with your MongoDB Atlas credentials and connection details
username = "qwerty123"
password = "qwerty123"
cluster_uri = "cluster0.zrw3uzs.mongodb.net"
database_name = "LinReg"
collection_name = "LinReg123"

# Construct the MongoDB Atlas connection string
connection_string = f"mongodb+srv://qwerty123:qwerty123@cluster0.zrw3uzs.mongodb.net/"


# Connect to MongoDB Atlas
client = pymongo.MongoClient(connection_string, ssl=True)

# Access the specified database and collection
database = client["LinReg"]
collection = database["LinReg123"]

# Fetch JSON data from the collection
json_data = list(collection.find())
print(json_data)

# # Convert the PyMongo Cursor to a list of dictionaries
# # Note: This step is optional if you want to work with a list of dictionaries
# json_data_list = [json.loads(json.dumps(item, default=str)) for item in json_data]

# # Now 'json_data' contains the JSON documents from the collection
# # You can print or further process the JSON data as needed
# for document in json_data_list:
#     print(json.dumps(document, indent=2))

# cursor=collection.find({})
# data_from_db=list(cursor)

# for document in cursor :
#     print(document)
# Out:
# [{'_id': ObjectId('65a15274e9adefb66ffde582'), 'YearsExperience': 1.1, 'Salary': 39343}, {'_id': ObjectId('65a15274e9adefb66ffde583'), 'YearsExperience': 1.3, 'Salary': 46205}, {'_id': ObjectId('65a15274e9adefb66ffde584'), 'YearsExperience': 1.5, 'Salary': 37731}, {'_id': ObjectId('65a15274e9adefb66ffde585'), 'YearsExperience': 2, 'Salary': 43525}, {'_id': ObjectId('65a15274e9adefb66ffde586'), 'YearsExperience': 2.2, 'Salary': 39891}, {'_id': ObjectId('65a15274e9adefb66ffde587'), 'YearsExperience': 2.9, 'Salary': 56642}, {'_id': ObjectId('65a15274e9adefb66ffde588'), 'YearsExperience': 3, 'Salary': 60150}, {'_id': ObjectId('65a15274e9adefb66ffde589'), 'YearsExperience': 3.2, 'Salary': 54445}, {'_id': ObjectId('65a15274e9adefb66ffde58a'), 'YearsExperience': 3.2, 'Salary': 64445}, {'_id': ObjectId('65a15274e9adefb66ffde58b'), 'YearsExperience': 3.7, 'Salary': 57189}, {'_id': ObjectId('65a15274e9adefb66ffde58c'), 'YearsExperience': 3.9, 'Salary': 63218}, {'_id': ObjectId('65a15274e9adefb
# ...

# %%
collection = database["LinReg123"]
json_data = list(collection.find())

# %%
df = pd.DataFrame(json_data)
df
# Out:
#                          _id  YearsExperience  Salary
# 0   65a15274e9adefb66ffde582              1.1   39343
# 1   65a15274e9adefb66ffde583              1.3   46205
# 2   65a15274e9adefb66ffde584              1.5   37731
# 3   65a15274e9adefb66ffde585              2.0   43525
# 4   65a15274e9adefb66ffde586              2.2   39891
# 5   65a15274e9adefb66ffde587              2.9   56642
# 6   65a15274e9adefb66ffde588              3.0   60150
# 7   65a15274e9adefb66ffde589              3.2   54445
# 8   65a15274e9adefb66ffde58a              3.2   64445
# 9   65a15274e9adefb66ffde58b              3.7   57189
# 10  65a15274e9adefb66ffde58c              3.9   63218
# 11  65a15274e9adefb66ffde58d              4.0   55794
# 12  65a15274e9adefb66ffde58e              4.0   56957
# 13  65a15274e9adefb66ffde58f              4.1   57081
# 14  65a15274e9adefb66ffde590              4.5   61111
# 15  65a15274e9adefb66ffde591              4.9   67938
# ...

# %%
df = df.drop('_id', axis=1)

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# ...

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        35.000000      35.000000
# mean          6.308571   83945.600000
# std           3.618610   32162.673003
# min           1.100000   37731.000000
# 25%           3.450000   57019.000000
# 50%           5.300000   81363.000000
# 75%           9.250000  113223.500000
# max          13.500000  139465.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 9))
sns.boxplot(df)

plt.title('Box Plot to Identify Outliers')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = df[['YearsExperience']]
y = df['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=800)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 38780606.909221396

# %%
plt.scatter(X_test['YearsExperience'], y_test ,color = "black")
plt.scatter(X_test['YearsExperience'], y_pred ,color = "blue")
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.title('Linear Regression: Actual vs. Predicted Salary')
plt.show()

# %%
result_df = pd.DataFrame({'YearsExperience': X_test['YearsExperience'], 'Actual': y_test, 'Predicted': y_pred})

# %%
result_df
# Out:
#     YearsExperience  Actual      Predicted
# 5               2.9   56642   53890.199364
# 0               1.1   39343   38096.189499
# 10              3.9   63218   62664.649290
# 33             12.9  135675  141634.698618
# 27              9.6  112635  112679.013864
# 14              4.5   61111   67929.319245
# 23              8.2  113812  100394.783969

# %%
result_df.mean()
# Out:
# YearsExperience        6.157143
# Actual             83205.142857
# Predicted          82469.836264
# dtype: float64

# %%
if result_df["Actual"].mean() >= result_df["Predicted"].mean():
    acc = result_df["Predicted"].mean()/result_df["Actual"].mean() *100
    print(acc)

else:
    acc = result_df["Actual"].mean()/result_df["Predicted"].mean() *100
    print(acc)
# Out:
# 99.11627266324491

# %%
plt.figure(figsize=(15, 9))
sns.boxplot(result_df)

plt.title('Box Plot to Identify Outliers')
plt.show()
